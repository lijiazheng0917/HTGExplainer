# %%
import dgl
from dgl.data.utils import load_graphs

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

from model.model_gcn import HTGNN, LinkPredictor
from utils.pytorchtools import EarlyStopping
from utils.utils import compute_metric, compute_loss
from utils.data import load_MAG_data

dgl.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)

# %%
def evaluate(model, val_feats, val_labels):
    val_mae_list, val_rmse_list = [], []
    model.eval()
    with torch.no_grad():
        for (G_feat, (pos_label, neg_label)) in zip(val_feats, val_labels):

            G_feat = G_feat.to(device)
            pos_label = pos_label.to(device)
            neg_label = neg_label.to(device)

            h = model[0](G_feat, 'author')
            pos_score = model[1](pos_label, h)
            neg_score = model[1](neg_label, h)

            loss = compute_loss(pos_score, neg_score, device)
            auc, ap = compute_metric(pos_score, neg_score)
    
    return auc, ap

# %%
htgnn = HTGNN(graph=graph_atom, n_inp=128, n_hid=32, n_layers=2, n_heads=1, time_window=time_window, norm=True, device=device)
predictor = LinkPredictor(n_inp=32, n_classes=1)
model = nn.Sequential(htgnn, predictor).to(device)
model.load_state_dict(torch.load('/home/jiazhengli/xdgnn/HTGNN/output/OGBN-MAG/checkpoint_HTGNN_0.pt'))
# Out:
# <All keys matched successfully>

# %%
glist, label_dict = load_graphs('data/ogbn_graphs.bin')

# %%
len(glist)
# Out:
# 10

# %%
glist, label_dict = load_graphs('data/ogbn_graphs.bin')
device = torch.device('cuda:0')
time_window = 5

train_feats, train_labels, val_feats, val_labels, test_feats, test_labels = load_MAG_data(glist, time_window, device)

graph_atom = test_feats[0]
model_out_path = 'output/OGBN-MAG'
auc_list, ap_list = [], []

for k in range(1):
    htgnn = HTGNN(graph=graph_atom, n_inp=128, n_hid=32, n_layers=2, n_heads=1, time_window=time_window, norm=True, device=device)
    predictor = LinkPredictor(n_inp=32, n_classes=1)
    model = nn.Sequential(htgnn, predictor).to(device)

    print(f'---------------Repeat time: {k+1}---------------------')
    print(f'# params: {sum(p.numel() for p in model.parameters() if p.requires_grad)}')
    optim = torch.optim.Adam(model.parameters(), lr=5e-3, weight_decay=5e-4)

    early_stopping = EarlyStopping(patience=50, verbose=True, path=f'{model_out_path}/checkpoint_HTGNN_{k}_w5.pt')
    for epoch in range(500):
        model.train()
        for (G_feat, (pos_label, neg_label)) in zip(train_feats, train_labels):

            G_feat = G_feat.to(device)

            pos_label = pos_label.to(device)
            neg_label = neg_label.to(device)

            h = model[0](G_feat, 'author')

            pos_score = model[1](pos_label, h)
            neg_score = model[1](neg_label, h)
            
            loss = compute_loss(pos_score, neg_score, device)
            auc, ap = compute_metric(pos_score, neg_score)

            optim.zero_grad()
            loss.backward()
            optim.step()
        
        auc, ap = evaluate(model, val_feats, val_labels)
        early_stopping(loss, model)

        if early_stopping.early_stop:
            print("Early stopping")
            break

    model.load_state_dict(torch.load(f'{model_out_path}/checkpoint_HTGNN_{k}_w5.pt'))
    auc, ap = evaluate(model, test_feats, test_labels)

    print(f'auc: {auc}, ap: {ap}')
    auc_list.append(auc)
    ap_list.append(ap)
# Out:
# loading mp2vec
# generating train, val, test sets
# ---------------Repeat time: 1---------------------
# # params: 164425
# Validation loss decreased (inf --> 0.782635).  Saving model ...
# Validation loss decreased (0.782635 --> 0.659126).  Saving model ...
# Validation loss decreased (0.659126 --> 0.638127).  Saving model ...
# Validation loss decreased (0.638127 --> 0.629834).  Saving model ...
# Validation loss decreased (0.629834 --> 0.618728).  Saving model ...
# Validation loss decreased (0.618728 --> 0.578556).  Saving model ...
# Validation loss decreased (0.578556 --> 0.538884).  Saving model ...
# Validation loss decreased (0.538884 --> 0.527804).  Saving model ...
# Validation loss decreased (0.527804 --> 0.511724).  Saving model ...
# Validation loss decreased (0.511724 --> 0.505019).  Saving model ...
# Validation loss decreased (0.505019 --> 0.490130).  Saving model ...
# Validation loss decreased (0.490130 --> 0.476205).  Saving model ...
# Validation loss decreased (0.476205 --> 0.469748).  Saving model ...
# Validation loss decreased (0.469748 --> 0.456917).  Saving model ...
# Validation loss decreased (0.456917 --> 0.451011).  Saving model ...
# Validation loss decreased (0.451011 --> 0.437437).  Saving model ...
# Validation loss decreased (0.437437 --> 0.427830).  Saving model ...
# Validation loss decreased (0.427830 --> 0.419657).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.419657 --> 0.409413).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.409413 --> 0.395533).  Saving model ...
# Validation loss decreased (0.395533 --> 0.390854).  Saving model ...
# Validation loss decreased (0.390854 --> 0.381326).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.381326 --> 0.375224).  Saving model ...
# Validation loss decreased (0.375224 --> 0.372743).  Saving model ...
# Validation loss decreased (0.372743 --> 0.365212).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.365212 --> 0.356636).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.356636 --> 0.352201).  Saving model ...
# Validation loss decreased (0.352201 --> 0.344124).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.344124 --> 0.343841).  Saving model ...
# Validation loss decreased (0.343841 --> 0.339834).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.339834 --> 0.332731).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.332731 --> 0.330707).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.330707 --> 0.328830).  Saving model ...
# Validation loss decreased (0.328830 --> 0.321476).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.321476 --> 0.315273).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.315273 --> 0.314374).  Saving model ...
# Validation loss decreased (0.314374 --> 0.312042).  Saving model ...
# Validation loss decreased (0.312042 --> 0.308355).  Saving model ...
# Validation loss decreased (0.308355 --> 0.303238).  Saving model ...
# Validation loss decreased (0.303238 --> 0.302777).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.302777 --> 0.301978).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# Validation loss decreased (0.301978 --> 0.299023).  Saving model ...
# Validation loss decreased (0.299023 --> 0.292919).  Saving model ...
# Validation loss decreased (0.292919 --> 0.292107).  Saving model ...
# Validation loss decreased (0.292107 --> 0.289065).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.289065 --> 0.284598).  Saving model ...
# Validation loss decreased (0.284598 --> 0.281495).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.281495 --> 0.280393).  Saving model ...
# Validation loss decreased (0.280393 --> 0.279226).  Saving model ...
# Validation loss decreased (0.279226 --> 0.278100).  Saving model ...
# Validation loss decreased (0.278100 --> 0.276405).  Saving model ...
# Validation loss decreased (0.276405 --> 0.271837).  Saving model ...
# Validation loss decreased (0.271837 --> 0.269633).  Saving model ...
# Validation loss decreased (0.269633 --> 0.269044).  Saving model ...
# Validation loss decreased (0.269044 --> 0.268725).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.268725 --> 0.266144).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# Validation loss decreased (0.266144 --> 0.264523).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# Validation loss decreased (0.264523 --> 0.258697).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.258697 --> 0.252984).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# Validation loss decreased (0.252984 --> 0.252638).  Saving model ...
# Validation loss decreased (0.252638 --> 0.251232).  Saving model ...
# Validation loss decreased (0.251232 --> 0.248232).  Saving model ...
# Validation loss decreased (0.248232 --> 0.247477).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.247477 --> 0.243801).  Saving model ...
# Validation loss decreased (0.243801 --> 0.242645).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.242645 --> 0.240096).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# Validation loss decreased (0.240096 --> 0.238890).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.238890 --> 0.238868).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# Validation loss decreased (0.238868 --> 0.238379).  Saving model ...
# Validation loss decreased (0.238379 --> 0.235972).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.235972 --> 0.235761).  Saving model ...
# Validation loss decreased (0.235761 --> 0.232631).  Saving model ...
# Validation loss decreased (0.232631 --> 0.229604).  Saving model ...
# Validation loss decreased (0.229604 --> 0.229431).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# Validation loss decreased (0.229431 --> 0.229059).  Saving model ...
# Validation loss decreased (0.229059 --> 0.227358).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.227358 --> 0.224517).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.224517 --> 0.222797).  Saving model ...
# Validation loss decreased (0.222797 --> 0.222550).  Saving model ...
# Validation loss decreased (0.222550 --> 0.222545).  Saving model ...
# Validation loss decreased (0.222545 --> 0.221466).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# Validation loss decreased (0.221466 --> 0.221197).  Saving model ...
# Validation loss decreased (0.221197 --> 0.219789).  Saving model ...
# Validation loss decreased (0.219789 --> 0.219024).  Saving model ...
# Validation loss decreased (0.219024 --> 0.218519).  Saving model ...
# Validation loss decreased (0.218519 --> 0.217557).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# Validation loss decreased (0.217557 --> 0.216750).  Saving model ...
# Validation loss decreased (0.216750 --> 0.216345).  Saving model ...
# Validation loss decreased (0.216345 --> 0.216092).  Saving model ...
# Validation loss decreased (0.216092 --> 0.215058).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# Validation loss decreased (0.215058 --> 0.212436).  Saving model ...
# Validation loss decreased (0.212436 --> 0.211212).  Saving model ...
# Validation loss decreased (0.211212 --> 0.210077).  Saving model ...
# Validation loss decreased (0.210077 --> 0.209650).  Saving model ...
# Validation loss decreased (0.209650 --> 0.208421).  Saving model ...
# Validation loss decreased (0.208421 --> 0.208087).  Saving model ...
# Validation loss decreased (0.208087 --> 0.207680).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# Validation loss decreased (0.207680 --> 0.206317).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.206317 --> 0.204998).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# EarlyStopping counter: 43 out of 50
# EarlyStopping counter: 44 out of 50
# EarlyStopping counter: 45 out of 50
# EarlyStopping counter: 46 out of 50
# EarlyStopping counter: 47 out of 50
# EarlyStopping counter: 48 out of 50
# EarlyStopping counter: 49 out of 50
# EarlyStopping counter: 50 out of 50
# Early stopping
# auc: 0.8772726442103064, ap: 0.8512438791122614

# %%
import statistics

print(f'AUC: {statistics.mean(auc_list)}, {statistics.stdev(auc_list)}')
print(f'AP: {statistics.mean(ap_list)}, {statistics.stdev(ap_list)}')
# Out:
# AUC: 0.9100877512024033, 0.007723909849077316
# AP: 0.8917769733866674, 0.01237942594912229
